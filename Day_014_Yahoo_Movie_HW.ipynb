# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = 'https://movies.yahoo.com.tw/'
res=requests.get(url)
soup=bs(res.text)

# %%
movie=dict()
for i in soup.find("select",id="sbox_mid").find_all("option"):
    if(i.get("data-name")):
        movie.update({i.get("data-name"):i.get("value")})
        print("名稱 :",i.get("data-name"))
        print("ID :",i.get("value"))
        print("---------------------------")
# Out:
# 名稱 : 電影版 地獄少女
# ID : 10525
# ---------------------------
# 名稱 : 刺激1995
# ID : 10518
# ---------------------------
# 名稱 : 通靈少年2020
# ID : 10517
# ---------------------------
# 名稱 : 安雅的回家路
# ID : 10516
# ---------------------------
# 名稱 : 牆內的房客
# ID : 10512
# ---------------------------
# 名稱 : 南山的部長們
# ID : 10509
# ---------------------------
# 名稱 : 另類神父
# ID : 10500
# ---------------------------
# 名稱 : 破．局
# ID : 10496
# ---------------------------
# 名稱 : 劇場版 不起眼女主角培育法 Fine
# ID : 10486
# ---------------------------
# 名稱 : 複製柔伊
# ID : 10455
# ---------------------------
# 名稱 : 練愛iNG
# ID : 10442
# ---------------------------
# 名稱 : 鋼鐵勳章
# ID : 10432
# ---------------------------
# 名稱 : 我，最親愛的
# ID : 10503
# ---------------------------
# 名稱 : 血衛
# ID : 10469
# ---------------------------
# 名稱 : 導演先生的完美假期
# ID : 10545
# ---------------------------
# 名稱 : 大地蜜語
# ID : 10513
# ---------------------------
# 名稱 : 狂飆一夢
# ID : 10506
# ---------------------------
# 名稱 : 親愛的莎瑪
# ID : 10491
# ...

# %%
import json
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
movie_area=dict()
for title in movie:
    print(title)
    movie_area.update({title:list()})
    params={"movie_id":movie[title]}
    res=requests.get(url,params=params,headers=headers)
    for info in res.json():
        print(info["title"],info["area_id"],sep=" : ")
        movie_area[title].append((info["title"],str(info["area_id"])))
    print("----------------------------------------------")
# Out:
# 電影版 地獄少女
# 台北市 : 28
# 新北市 : 8
# 桃園 : 16
# 新竹 : 20
# 台中 : 2
# 台南 : 10
# 高雄 : 17
# 屏東 : 14
# 宜蘭 : 11
# ----------------------------------------------
# 刺激1995
# 台北市 : 28
# 新北市 : 8
# 桃園 : 16
# 新竹 : 20
# 台中 : 2
# 台南 : 10
# 高雄 : 17
# ----------------------------------------------
# 通靈少年2020
# 台北市 : 28
# 新北市 : 8
# 桃園 : 16
# 新竹 : 20
# 苗栗 : 15
# 台中 : 2
# 嘉義 : 21
# 台南 : 10
# 高雄 : 17
# 屏東 : 14
# 宜蘭 : 11
# 花蓮 : 12
# 金門 : 24
# 澎湖 : 23
# ----------------------------------------------
# 安雅的回家路
# 台北市 : 28
# 新北市 : 8
# 桃園 : 16
# 新竹 : 20
# 台中 : 2
# 嘉義 : 21
# 台南 : 10
# 高雄 : 17
# 宜蘭 : 11
# ----------------------------------------------
# 牆內的房客
# 台北市 : 28
# 桃園 : 16
# 台南 : 10
# 高雄 : 17
# ----------------------------------------------
# 南山的部長們
# 台北市 : 28
# 新北市 : 8
# 桃園 : 16
# 新竹 : 20
# 苗栗 : 15
# 台中 : 2
# 台南 : 10
# 高雄 : 17
# 金門 : 24
# ----------------------------------------------
# 另類神父
# 台北市 : 28
# 桃園 : 16
# 台中 : 2
# 台南 : 10
# 高雄 : 17
# ----------------------------------------------
# 破．局
# 台北市 : 28
# ...

# %%
movie_area
# Out:
# {'電影版 地獄少女': [('台北市', '28'),
#   ('新北市', '8'),
#   ('桃園', '16'),
#   ('新竹', '20'),
#   ('台中', '2'),
#   ('台南', '10'),
#   ('高雄', '17'),
#   ('屏東', '14'),
#   ('宜蘭', '11')],
#  '刺激1995': [('台北市', '28'),
#   ('新北市', '8'),
#   ('桃園', '16'),
#   ('新竹', '20'),
#   ('台中', '2'),
#   ('台南', '10'),
#   ('高雄', '17')],
#  '通靈少年2020': [('台北市', '28'),
#   ('新北市', '8'),
#   ('桃園', '16'),
#   ('新竹', '20'),
#   ('苗栗', '15'),
#   ('台中', '2'),
#   ('嘉義', '21'),
#   ('台南', '10'),
#   ('高雄', '17'),
#   ('屏東', '14'),
#   ('宜蘭', '11'),
#   ('花蓮', '12'),
#   ('金門', '24'),
#   ('澎湖', '23')],
#  '安雅的回家路': [('台北市', '28'),
#   ('新北市', '8'),
#   ('桃園', '16'),
#   ('新竹', '20'),
#   ('台中', '2'),
#   ('嘉義', '21'),
#   ('台南', '10'),
#   ('高雄', '17'),
#   ('宜蘭', '11')],
#  '牆內的房客': [('台北市', '28'), ('桃園', '16'), ('台南', '10'), ('高雄', '17')],
#  '南山的部長們': [('台北市', '28'),
#   ('新北市', '8'),
#   ('桃園', '16'),
#   ('新竹', '20'),
#   ('苗栗', '15'),
#   ('台中', '2'),
#   ('台南', '10'),
#   ('高雄', '17'),
#   ('金門', '24')],
# ...

# %%
movie
# Out:
# {'電影版 地獄少女': '10525',
#  '刺激1995': '10518',
#  '通靈少年2020': '10517',
#  '安雅的回家路': '10516',
#  '牆內的房客': '10512',
#  '南山的部長們': '10509',
#  '另類神父': '10500',
#  '破．局': '10496',
#  '劇場版 不起眼女主角培育法 Fine': '10486',
#  '複製柔伊': '10455',
#  '練愛iNG': '10442',
#  '鋼鐵勳章': '10432',
#  '我，最親愛的': '10503',
#  '血衛': '10469',
#  '導演先生的完美假期': '10545',
#  '大地蜜語': '10513',
#  '狂飆一夢': '10506',
#  '親愛的莎瑪': '10491',
#  '大畫特務': '10478',
#  '戰慄糖果屋': '10472',
#  '失戀殺人：三角禁戀': '10465',
#  '明明會說話': '10440',
#  '艾瑪': '10396',
#  '罪樂園': '10349',
#  '千日千夜': '10490',
#  '鳴鳥不飛：烏雲密布': '10458',
#  '哥布林殺手 劇場版': '10438',
#  '女鬼橋': '10437',
#  '怨咒': '10421',
#  '極地守護犬': '10383',
#  '叔．叔': '10371',
#  '隱形人': '10359',
#  '失路人': '10498',
#  '電影音效傳奇：好萊塢之聲': '10484',
#  '悲慘世界': '10479',
#  '吹哨奇案': '10475',
#  '陰櫥': '10457',
#  '絕命大平台': '10447',
#  '李察朱威爾事件': '10368',
#  '音速小子': '9246',
#  '逃出夢幻島': '10485',
#  '雨天．紐約': '10476',
#  '超＂人＂氣動物園': '10445',
#  '全境失控': '10426',
#  '猛禽小隊：小丑女大解放': '10268',
#  '熱帶雨': '10448',
# ...

# %%
url="https://movies.yahoo.com.tw/movietime_result.html"
for i in movie:
    print(i)
    for j in movie_area[i]:
        print(j[0])
        params={"movie_id":movie[i],"area_id":j[1]}
        res=requests.get(url,params=params)
        soup=bs(res.text)
        label=soup.find_all("label",class_="picker_label")
        for l in label:
            print(l.p.text,l.h3.text)
    print("----------------------------------------")
# Out:
# 電影版 地獄少女
# 台北市
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 新北市
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 桃園
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 新竹
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 台中
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 台南
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 高雄
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 屏東
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 宜蘭
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# ----------------------------------------
# 刺激1995
# 台北市
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 新北市
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 桃園
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 新竹
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 台中
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 台南
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 高雄
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# ----------------------------------------
# 通靈少年2020
# 台北市
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 新北市
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 桃園
# 三月 15
# 三月 16
# 三月 17
# 三月 18
# 三月 19
# 新竹
# 三月 15
# 三月 16
# ...

# %%
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
date="2020-03-16"
for i in movie:
    print(i)
    for j in movie_area[i]:
        print
        params={"movie_id":movie[i]
                ,"area_id":j[1]
                ,'date':date
                ,'theater_id':''
                ,'datetime':''
                ,'movie_type_id':''}
        res=requests.get(url,params=params)
        soup=bs(res.json()["view"])
        #print(soup.find("div",class_="area_title"))
        for m in soup.find_all("ul",class_="area_time _c jq_area_time"):
            print("電影院:",m.find("a").text)
            print("放映類型:",m.find("span",class_="tapR").text)
            for t in m.find_all("label",class_="select"):
                print(date,t.text)
    print("-------------------------------------------")
# Out:
# 電影版 地獄少女
# 電影院: 台北樂聲影城
# 放映類型: 數位
# 2020-03-16 16:15
# 2020-03-16 20:15
# 2020-03-16 22:25
# 電影院: 喜滿客絕色影城
# 放映類型: 數位
# 2020-03-16 11:00
# 2020-03-16 15:10
# 2020-03-16 19:20
# 2020-03-16 23:30
# 電影院: 台北信義威秀影城
# 放映類型: 數位
# 2020-03-16 12:50
# 2020-03-16 17:00
# 2020-03-16 21:10
# 電影院: 喜樂時代影城南港店
# 放映類型: 數位
# 2020-03-16 15:00
# 2020-03-16 17:05
# 2020-03-16 19:10
# 2020-03-16 21:15
# 電影院: 桃園統領威秀影城
# 放映類型: 數位
# 2020-03-16 15:35
# 2020-03-16 19:55
# 2020-03-16 23:00
# 電影院: 新竹大遠百威秀影城
# 放映類型: 數位
# 2020-03-16 14:45
# 2020-03-16 21:20
# 電影院: 台中新時代凱擘影城
# 放映類型: 數位
# 2020-03-16 10:45
# 2020-03-16 15:10
# 2020-03-16 19:20
# 2020-03-16 23:00
# 電影院: 台中新光影城
# 放映類型: 數位
# 2020-03-16 11:15
# 2020-03-16 15:50
# 2020-03-16 19:45
# 電影院: 台南大遠百威秀影城
# 放映類型: 數位
# 2020-03-16 18:05
# 2020-03-16 21:55
# 電影院: 台南新光影城
# 放映類型: 數位
# 2020-03-16 13:00
# 2020-03-16 15:05
# 2020-03-16 17:15
# 2020-03-16 19:25
# 電影院: 高雄大遠百威秀影城
# 放映類型: 數位
# 2020-03-16 13:00
# 2020-03-16 19:10
# 2020-03-16 23:20
# 電影院: 喜滿客夢時代影城
# 放映類型: 數位
# ...
